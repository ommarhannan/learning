# %% [markdown]
# # Classification Metrics
#
# During the course of this notebook, you will calculate several classification metrics for a random forest classifier model.

# %%
from sklearn.datasets import make_blobs
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt

# %% [markdown]
# ## Dataset Setup
#
# In the cell below, we use the `make_blobs` utility function ([documentation here](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_blobs.html)) to automatically generate `X` and `y` data.
#
# The `random_state` argument ensures that we will generate the same dataset every time.

# %%
# Begin by creating a dataset using Sklearn

X, y = make_blobs(n_samples=200, n_features=3, shuffle=True, random_state=111)

# %%
X
# Out:
# array([[  2.89275396,  -5.55396951,  -1.39118898],
#        [ -9.41418915,  -1.75400777,  -3.63546455],
#        [ -9.93446157,  -2.66511812,  -4.61562457],
#        [ -9.47672369,  -3.36291044,  -5.61486931],
#        [  1.67862952,  -6.93239943,  -0.10412476],
#        [  5.08485017,  -2.86403549,  -6.76451521],
#        [  6.02054992,  -1.96635062,  -4.8656881 ],
#        [  1.61241641,  -5.96004174,  -1.51280101],
#        [  0.59526132,  -7.524045  ,  -1.36391022],
#        [  1.58331498,  -7.39955057,  -1.33681733],
#        [-10.1122394 ,  -1.79299261,  -4.83470366],
#        [  5.39169391,  -3.90654619,  -5.86487289],
#        [  1.58836262,  -7.36026568,  -0.93873535],
#        [ -9.87704613,  -1.22580255,  -4.34789612],
#        [  2.33114959,  -6.17331601,  -0.56948526],
#        [-10.67820884,  -2.35701221,  -5.37739021],
#        [-10.16503625,  -0.95661089,  -6.41187939],
#        [ -8.15927819,  -1.83248055,  -5.77797046],
#        [  3.49372786,  -6.98277187,  -0.17535234],
#        [  2.51608326,  -5.64576584,   1.29036141],
#        [ -9.7188738 ,  -2.07647034,  -5.59699704],
#        [-10.33096687,  -1.40543143,  -4.56201267],
#        [  4.10440294,  -8.98131185,   0.06082891],
#        [ -9.8509416 ,  -1.51468801,  -4.15922161],
#        [  6.64016878,  -5.40495117,  -8.32857661],
#        [  7.22791191,  -5.17355447,  -5.96230624],
#        [  6.06783542,  -5.16753203,  -7.05005071],
#        [  3.17308702,  -2.22713018,  -6.92598518],
#        [ -9.35632113,  -1.91713309,  -5.58028482],
#        [ -9.28630321,  -1.76444124,  -5.49861621],
#        [  3.14339702,  -5.41471509,  -1.65758218],
#        [  3.81026317,  -6.36592484,  -6.61889064],
#        [  3.76512919,  -6.88068551,  -3.03033644],
#        [  4.65846059,  -3.23545183,  -6.83463675],
#        [-10.06468797,   0.72247031,  -4.00926606],
#        [  3.3173253 ,  -6.33396837,  -2.49572542],
#        [ -9.81289852,  -2.94528604,  -7.31730803],
#        [  7.0990123 ,  -3.696185  ,  -5.94905706],
#        [  6.13372329,  -3.37600813,  -6.73200071],
#        [ -9.44289392,  -0.49931179,  -4.82823535],
#        [ -6.71564003,  -2.45177437,  -5.94720675],
#        [  4.89601364,  -3.14837032,  -6.80932772],
#        [  3.47208007,  -6.89501819,   0.04392965],
#        [  5.82609259,  -3.46075272,  -6.19767308],
#        [ -6.99540828,  -1.40576371,  -6.15913242],
#        [  1.51903117,  -7.12403677,   0.05250256],
#        [  3.4754363 ,  -6.89435785,  -6.77263155],
#        [ -9.96539663,  -1.14644513,  -4.6359361 ],
#        [ -9.06909189,  -1.21320354,  -5.71200728],
#        [  1.44688024,  -3.97260613,  -0.77682006],
#        [  6.2000956 ,  -5.30652866,  -7.3787234 ],
#        [  4.5498276 ,  -6.202426  ,  -8.87738858],
#        [  2.28081922,  -6.96297629,   0.16641817],
#        [  3.29091627,  -6.46653466,  -2.07699464],
#        [ -7.76842957,  -2.03708123,  -2.94776737],
#        [-10.78159616,  -2.8364886 ,  -5.38715129],
#        [  4.15924647,  -7.55856944,   1.05557404],
#        [  4.54909527,  -4.54125742,  -9.40606759],
#        [  5.63892782,  -3.64261512,  -7.32793459],
#        [ -9.69889268,  -1.35762658,  -6.54823032],
#        [  3.80282881,  -6.79876977,  -1.9453574 ],
#        [-10.02006793,  -2.82121612,  -6.24151194],
#        [-10.04129279,  -1.16952682,  -3.90207894],
#        [ -9.20374812,   0.08587264,  -7.10765081],
#        [  5.77370956,  -4.66375266,  -5.97535508],
#        [  5.78884562,  -4.95465924,  -8.06393805],
#        [  2.33006958,  -4.96230115,  -2.34334004],
#        [  6.1013214 ,  -4.14729585,  -7.51774278],
#        [  4.16001489,  -3.23609166,  -7.9053057 ],
#        [  6.65182204,  -3.93178175,  -5.50006291],
#        [  1.93742826,  -5.25230018,   0.59779913],
#        [  5.21628522,  -3.69248161,  -7.89624602],
#        [ -9.93853049,  -2.06883071,  -5.73585468],
#        [  1.32883869,  -6.69414432,  -1.71475161],
#        [  4.06084012,  -3.0528404 ,  -7.34877906],
#        [  4.25802517,  -4.34708645,  -8.16938259],
#        [  3.48179546,  -3.47980249,  -4.90243171],
#        [ -9.46041461,   0.08394472,  -5.18251712],
#        [  2.90402711,  -7.40298232,  -1.45901078],
#        [  5.92053646,  -5.3396116 ,  -7.85191169],
#        [  2.90802492,  -6.24798216,  -0.57714545],
#        [  4.81060643,  -3.53025422,  -8.26157158],
#        [ -9.31231522,  -0.10109428,  -4.15371986],
#        [  6.2094848 ,  -3.69603748,  -5.50678301],
#        [  4.37656654,  -4.46086164,  -7.29918627],
#        [-10.40996275,  -0.06422233,  -5.11605955],
#        [  5.7085973 ,  -4.80492924,  -6.71638751],
#        [  2.9859175 ,  -8.3558419 ,  -1.46000873],
#        [  4.19759761,  -4.6616508 ,  -6.73915414],
#        [  1.34950001,  -6.63160262,   0.46470807],
#        [  1.92238313,  -5.33844657,  -1.32277982],
#        [  1.00560711,  -9.30148461,  -2.66599575],
#        [  3.95328465,  -6.66764379,  -0.63336379],
#        [  4.71965529,  -3.83472597,  -6.84221131],
#        [-10.35543526,   0.75593378,  -6.51478111],
#        [  2.11531176,  -6.65258413,  -1.43872398],
#        [  6.36514295,  -4.64473313,  -6.91750095],
#        [  2.64434277,  -6.59447725,  -1.12552589],
#        [  6.96087647,  -5.32001045,  -7.79685373],
#        [  3.93916921,  -2.65888986,  -5.44054875],
#        [  2.42667883,  -6.15785657,  -2.99822524],
#        [  3.02028613,  -6.36832821,  -0.03287748],
#        [ -8.41001577,  -3.38631864,  -5.97852969],
#        [  0.88217085,  -7.94158655,  -1.39413234],
#        [  1.13952256,  -7.00167152,  -2.54183159],
#        [ -9.69723174,  -0.90577518,  -4.19329384],
#        [ -5.41146655,  -0.60270602,  -5.13755763],
#        [  4.99474155,  -4.39442203,  -6.98068408],
#        [-10.49689242,  -1.44603024,  -4.88436596],
#        [  3.72831159,  -4.25435362,  -7.37038838],
#        [  2.05956035,  -6.73373469,  -0.19097642],
#        [ -9.17659697,  -2.16979755,  -4.26337925],
#        [  2.5435815 ,  -6.83814397,  -2.57948891],
#        [  6.57209684,  -4.67719416,  -5.61059489],
#        [  4.82294638,  -2.86294903,  -6.64122631],
#        [  5.4542347 ,  -2.91372362,  -6.24958611],
#        [-10.82896083,  -1.93271266,  -6.56333258],
#        [  4.89147652,  -4.21119984,  -8.74682632],
#        [ -9.47930244,  -1.72644265,  -5.66905808],
#        [ -9.75214088,  -3.50706811,  -7.24636076],
#        [ -9.84039288,  -1.53773398,  -5.50017161],
#        [  3.63684849,  -6.69940357,  -0.82455437],
#        [ -8.11257077,  -1.91816559,  -4.81588496],
#        [  4.50658999,  -4.58394849,  -7.52393837],
#        [ -7.88545863,  -1.46739886,  -3.82242959],
#        [ -7.55100946,  -1.49115257,  -6.1192166 ],
#        [  5.68524561,  -4.52913989,  -7.49609205],
#        [-10.80179699,  -1.69623731,  -5.95633351],
#        [  5.26928697,  -3.03865767,  -8.33730859],
#        [  3.08566749,  -6.37413497,  -1.49504324],
#        [  3.35987028,  -3.45072183,  -5.50955149],
#        [ -9.05462823,  -1.90258565,  -3.16804356],
#        [  5.15368619,  -4.85117026,  -6.9702473 ],
#        [  4.77692545,  -4.14455545,  -7.45382023],
#        [  4.41765825,  -6.56330014,  -7.58613122],
#        [  1.98936231,  -5.84539257,  -2.21021127],
#        [ -8.94182444,  -0.2602787 ,  -6.85321862],
#        [  5.8912517 ,  -3.99156553,  -9.36103896],
#        [  2.01143478,  -7.61297787,  -2.14749463],
#        [  2.33478201,  -6.49402394,  -0.90773826],
#        [-10.26903009,  -1.11565767,  -4.40419192],
#        [  1.47353881,  -6.65062385,  -2.67252759],
#        [  2.60229128,  -5.15018084,  -2.63092581],
#        [ -8.65277655,  -2.27900719,  -5.44635869],
#        [  1.28009067,  -6.67561059,  -1.75093809],
#        [  4.55103515,  -2.69723994,  -7.31338338],
#        [  0.97530924,  -6.10024143,  -2.27834804],
#        [  2.23877044,  -5.7103411 ,   0.40262199],
#        [  1.35897615,  -6.24137748,  -0.90451052],
#        [  2.71641632,  -7.12920727,  -0.81026954],
#        [ -9.92269635,  -1.50179071,  -5.27211706],
#        [ -8.28587285,  -2.17292984,  -5.7218301 ],
#        [  3.07109589,  -4.75172366,  -5.58606921],
#        [-10.03512621,  -1.17751917,  -6.04659904],
#        [  2.09281229,  -6.6144566 ,   0.03206355],
#        [-12.66197095,  -1.26263321,  -5.40357682],
#        [ -9.7102136 ,  -1.18122414,  -4.64197204],
#        [  6.61690956,  -4.27615709,  -7.12017525],
#        [  1.84371438,  -7.52867117,  -0.10853705],
#        [  4.83441982,  -6.06299642,  -6.87490446],
#        [  2.48691197,  -8.13580916,  -1.71775177],
#        [  4.89872493,  -4.1399191 ,  -7.10562158],
#        [  5.60098508,  -4.37792256,  -8.19961307],
#        [ -7.84536982,  -0.8161232 ,  -5.90044616],
#        [  4.48707969,  -3.45418094,  -6.60185229],
#        [ -9.37818522,  -1.41276998,  -5.15374286],
#        [  2.56183139,  -7.61723435,  -3.8156029 ],
#        [  7.35519245,  -2.66460127,  -8.38709742],
#        [ -8.80682329,  -1.05459173,  -5.99715516],
#        [  5.70667898,  -4.0065567 ,  -6.4541863 ],
#        [  1.64874563,  -6.39201585,  -2.34947177],
#        [  4.70475683,  -4.20909156,  -8.99550336],
#        [  3.04542999,  -5.57238949,  -2.18361822],
#        [  5.79889231,  -3.07725072,  -5.61634531],
#        [  6.74780031,  -4.5103974 ,  -6.464394  ],
#        [  1.79046052,  -6.03171549,   0.49867296],
#        [ -9.66483379,  -1.34433656,  -5.50349547],
#        [  5.33554944,  -4.82073578,  -7.97506718],
#        [ -8.35502434,  -1.84746169,  -4.89077927],
#        [ -9.04058827,  -0.30150586,  -4.3381968 ],
#        [ -9.71158928,  -1.36465713,  -4.22704097],
#        [ -8.33397577,  -1.16273257,  -6.68852749],
#        [-10.77318799,   0.09128945,  -5.71636067],
#        [ -9.14372633,  -2.60701912,  -5.61422058],
#        [  2.89156629,  -5.01675084,  -3.08641349],
#        [ -8.78427796,  -0.77911684,  -5.32318697],
#        [  2.34861222,  -8.03003153,  -0.54615216],
#        [  1.84698621,  -5.99235886,  -0.2322204 ],
#        [  5.05748732,  -4.43205648,  -7.63960405],
#        [  0.93713574,  -6.81552526,  -0.61444342],
#        [  2.36545894,  -5.44287667,  -0.37508959],
#        [ -9.91156241,  -3.11721732,  -5.61223215],
#        [  2.57513906,  -6.39137332,  -2.32085873],
#        [  1.80348718,  -6.16978314,  -2.1381089 ],
#        [  0.95730663,  -6.10845618,  -0.4303535 ],
#        [  2.26957521,  -5.7464236 ,  -0.97897405],
#        [  1.65194446,  -7.38446473,  -1.20482957],
#        [  5.38072736,  -5.71936418,  -6.1937827 ],
#        [ -8.39136463,  -0.67274805,  -4.31970694],
#        [  4.56738547,  -3.28830296,  -6.2010916 ]])

# %%
y
# Out:
# array([0, 2, 2, 2, 0, 1, 1, 0, 0, 0, 2, 1, 0, 2, 0, 2, 2, 2, 0, 0, 2, 2,
#        0, 2, 1, 1, 1, 1, 2, 2, 0, 1, 0, 1, 2, 0, 2, 1, 1, 2, 2, 1, 0, 1,
#        2, 0, 1, 2, 2, 0, 1, 1, 0, 0, 2, 2, 0, 1, 1, 2, 0, 2, 2, 2, 1, 1,
#        0, 1, 1, 1, 0, 1, 2, 0, 1, 1, 1, 2, 0, 1, 0, 1, 2, 1, 1, 2, 1, 0,
#        1, 0, 0, 0, 0, 1, 2, 0, 1, 0, 1, 1, 0, 0, 2, 0, 0, 2, 2, 1, 2, 1,
#        0, 2, 0, 1, 1, 1, 2, 1, 2, 2, 2, 0, 2, 1, 2, 2, 1, 2, 1, 0, 1, 2,
#        1, 1, 1, 0, 2, 1, 0, 0, 2, 0, 0, 2, 0, 1, 0, 0, 0, 0, 2, 2, 1, 2,
#        0, 2, 2, 1, 0, 1, 0, 1, 1, 2, 1, 2, 0, 1, 2, 1, 0, 1, 0, 1, 1, 0,
#        2, 1, 2, 2, 2, 2, 2, 2, 0, 2, 0, 0, 1, 0, 0, 2, 0, 0, 0, 0, 0, 1,
#        2, 1])

# %% [markdown]
# Knowledge check: have we created a *binary* classification problem or a *multiclass* classification problem?
#
# <details>
#   <summary>Answer (click to expand)</summary>
#
#   Because we have 3 different values in `y`—`0`, `1`, and `2`—this is a **multiclass** classification problem. A binary classification problem would only have 2 different values.
#
# </details>

# %%
# Visualize the clusters using a scatterplot

fig, ax = plt.subplots()
ax.scatter(X[:,0], X[:,2], alpha=0.75)
ax.set_title("Visualizing the First and Third Feature")
ax.set_xlabel("First Feature")
ax.set_ylabel("Third Feature");

# %% [markdown]
# ## Training a Classifier
#
# Next, we train a random forest classifier ([documentation here](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html)) using our `X` and `y` data.

# %%
clf = RandomForestClassifier(max_depth=1,random_state=111)
clf.fit(X, y)
# Out:
# RandomForestClassifier(max_depth=1, random_state=111)

# %% [markdown]
# ## Your Task: Calculate Classification Metrics
#
# Generate predictions, then calculate the following classification metrics:
#
# 1. Precision ([documentation here](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.precision_score.html))
# 2. Recall ([documentation here](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.recall_score.html))
# 3. F1 Score ([documentation here](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.f1_score.html))
#
# Because this is a multiclass problem, you will need to specify an appropriate value for the `average` argument. Review the documentation to help make this selection.

# %%
# TODO: get predictions for X

predictions = clf.predict(X)

# %%
predictions
# Out:
# array([0, 2, 2, 2, 0, 1, 1, 0, 0, 0, 2, 1, 0, 2, 0, 2, 2, 2, 0, 0, 2, 2,
#        0, 2, 1, 1, 1, 2, 2, 2, 0, 1, 0, 1, 2, 0, 2, 1, 1, 2, 2, 1, 0, 1,
#        2, 0, 1, 2, 2, 0, 1, 1, 0, 0, 2, 2, 0, 1, 1, 2, 0, 2, 2, 2, 1, 1,
#        0, 1, 1, 1, 0, 1, 2, 0, 1, 1, 1, 2, 0, 1, 0, 1, 2, 1, 1, 2, 1, 0,
#        1, 0, 0, 0, 0, 1, 2, 0, 1, 0, 1, 1, 0, 0, 2, 0, 0, 2, 2, 1, 2, 1,
#        0, 2, 0, 1, 1, 1, 2, 1, 2, 2, 2, 0, 2, 1, 2, 2, 1, 2, 1, 0, 1, 2,
#        1, 1, 1, 0, 2, 1, 0, 0, 2, 0, 0, 2, 0, 1, 0, 0, 0, 0, 2, 2, 1, 2,
#        0, 2, 2, 1, 0, 1, 0, 1, 1, 2, 1, 2, 0, 1, 2, 1, 0, 1, 0, 1, 1, 0,
#        2, 1, 2, 2, 2, 2, 2, 2, 0, 2, 0, 0, 1, 0, 0, 2, 0, 0, 0, 0, 0, 1,
#        2, 1])

# %%
# TODO: import precision metric

from sklearn.metrics import precision_score

# TODO: calculate precision score for predictions
# According to the documentation, "micro" means "Calculate metrics globally by counting the total true positives,
# false negatives and false positives"

precision = precision_score(y, predictions, average='micro')

# %%
# TODO: import recall metric

from sklearn.metrics import recall_score

# TODO: calculate recall score for predictions

recall = recall_score(y, predictions, average='micro')

# %%
# TODO: import F1 score metric

from sklearn.metrics import f1_score

# TODO: calculate F1 score for predictions

f1 = f1_score(y, predictions, average='micro')

# %%
print("Precision: ", precision)
print("Recall: ", recall)
print("F1 Score: ", f1)
# Visualize the predictions using a scatterplot
fig, ax = plt.subplots()
ax.scatter(X[:,0], X[:,2], c=predictions, alpha=0.75)
ax.set_title("Visualizing the First and Third Feature with Predictions")
ax.set_xlabel("First Feature")
ax.set_ylabel("Third Feature")
plt.show()
# Out:
# Precision:  0.995
# Recall:  0.995
# F1 Score:  0.995
